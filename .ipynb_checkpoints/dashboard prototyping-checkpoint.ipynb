# %%
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from sklearn.cluster import KMeans, SpectralClustering, AgglomerativeClustering
from sklearn.metrics import silhouette_score

from sklearn.neighbors import NearestNeighbors
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances, euclidean_distances


# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv("data.csv", index_col=0)

data.columns = data.columns.str.lower().str.replace(" ", "_")

bad_cols = ["club_logo", "photo", "flag", "loaned_from"]

data = data.drop(bad_cols, axis = 1)
data = data.query("position != 'GK'")
gk_cols = [i for i in data.columns if "gk" in i]

data = data.drop(gk_cols, axis = 1)
data = data.set_index("id")

# %%
# Out:
# 651

# %%
top_5_club = []

# %%
for i in data.club.unique():
    q = input("{} Yah or nah: ".format(i))
    if q == "y":
        top_5_club.append(i)
# Out:
# FC Barcelona Yah or nah: y
# Juventus Yah or nah: y
# Paris Saint-Germain Yah or nah: y
# Manchester City Yah or nah: y
# Chelsea Yah or nah: y
# Real Madrid Yah or nah: y
# FC Bayern München Yah or nah: y
# Atlético Madrid Yah or nah: y
# Tottenham Hotspur Yah or nah: y
# Liverpool Yah or nah: y
# Napoli Yah or nah: y
# Arsenal Yah or nah: y
# Milan Yah or nah: y
# Inter Yah or nah: y
# Manchester United Yah or nah: y
# Lazio Yah or nah: y
# Borussia Dortmund Yah or nah: y
# Vissel Kobe Yah or nah: r
# Olympique Lyonnais Yah or nah: y
# Roma Yah or nah: y
# Valencia CF Yah or nah: y
# Guangzhou Evergrande Taobao FC Yah or nah: r
# FC Porto Yah or nah: y
# FC Schalke 04 Yah or nah: y
# Beşiktaş JK Yah or nah: r
# LA Galaxy Yah or nah: r
# Sporting CP Yah or nah: r
# Real Betis Yah or nah: y
# Olympique de Marseille Yah or nah: y
# RC Celta Yah or nah: y
# Real Sociedad Yah or nah: y
# Sevilla FC Yah or nah: y
# SL Benfica Yah or nah: y
# AS Monaco Yah or nah: y
# ...

# %%
len(top_5_club)
# Out:
# 102

# %%
data = data[data.club.isin(top_5_club)].copy()

# %%
# data = data[data.overall >= 70].copy()

# %%
attribute_cols = data.columns[48:-1].tolist()
features = data[attribute_cols].copy()
features.dropna(inplace=True)

# %%
features.columns
# Out:
# Index(['crossing', 'finishing', 'headingaccuracy', 'shortpassing', 'volleys',
#        'dribbling', 'curve', 'fkaccuracy', 'longpassing', 'ballcontrol',
#        'acceleration', 'sprintspeed', 'agility', 'reactions', 'balance',
#        'shotpower', 'jumping', 'stamina', 'strength', 'longshots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standingtackle', 'slidingtackle'],
#       dtype='object')

# %%
# off_cols = ["crossing", "finishing", "shortpassing", "dribbling", "longpassing", "ballcontrol",
#            "acceleration", "agility", "reactions", "balance", "shotpower", "composure"]
# features2 = features[off_cols].copy()

# %%
cols = ["finishing", "h"]

# %%
name = "Messi"

# %%
data[data.name.str.contains(name)].iloc[:, :17]
# Out:
#             name  age nationality  overall  potential          club    value  \
# id
# 158023  L. Messi   31   Argentina       94         94  FC Barcelona  €110.5M
#
#          wage  special preferred_foot  international_reputation  weak_foot  \
# id
# 158023  €565K     2202           Left                       5.0        4.0
#
#         skill_moves       work_rate body_type real_face position
# id
# 158023          4.0  Medium/ Medium     Messi       Yes       RF

# %%
data[data.name.str.contains(name)].index[0]
# Out:
# 158023

# %%
pulisic_id = data[data.name.str.contains(name)].index[0]
pulisic_id
# Out:
# 158023

# %%
scale = StandardScaler()
Xs = scale.fit_transform(features)

# %%
model = NearestNeighbors(n_neighbors=21, metric="cosine")
model.fit(Xs)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='cosine',
#          metric_params=None, n_jobs=None, n_neighbors=21, p=2, radius=1.0)

# %%
pulisic_data = features.loc[pulisic_id].values.reshape(1, -1)

# %%
pulisic_data_s = scale.transform(pulisic_data)

# %%
model.kneighbors(pulisic_data_s)
# Out:
# (array([[0.        , 0.0307018 , 0.03535501, 0.03933924, 0.05532732,
#          0.05679103, 0.06478336, 0.06494768, 0.06513571, 0.06731358,
#          0.06811651, 0.07032157, 0.07254413, 0.07426427, 0.0756943 ,
#          0.07718798, 0.07871933, 0.07898477, 0.07964478, 0.08036535,
#          0.082084  ]]),
#  array([[  0,   2,   4,  13, 110, 135,  69, 358,  58, 138,  20, 230,  27,
#          113,  18,  21, 116, 249, 163,  73, 183]]))

# %%
nearest_christian = model.kneighbors(pulisic_data_s)[1][0]
nearest_christian
# Out:
# array([  0,   2,   4,  13, 110, 135,  69, 358,  58, 138,  20, 230,  27,
#        113,  18,  21, 116, 249, 163,  73, 183])

# %%
display_cols = ["name", "age", "nationality", "overall", "potential", "club", "position"]

# %%
data.iloc[nearest_christian[1:],:][display_cols]
# Out:
#                    name  age     nationality  overall  potential  \
# id
# 190871        Neymar Jr   26          Brazil       92         93
# 183277        E. Hazard   27         Belgium       91         91
# 211110        P. Dybala   24       Argentina       89         94
# 204970       F. Thauvin   25          France       84         87
# 9014          A. Robben   34     Netherlands       84         84
# 220834    Marco Asensio   22           Spain       85         92
# 144622          Raffael   33          Brazil       81         81
# 188350          M. Reus   29         Germany       86         86
# 230481  Ronaldo Cabrais   26          Brazil       83         83
# 231747        K. Mbappé   19          France       88         95
# 199451    W. Ben Yedder   27          France       82         82
# 189242         Coutinho   26          Brazil       88         89
# 200104           H. Son   25  Korea Republic       84         85
# ...

# %%
cos_dist = pd.DataFrame(cosine_distances(features.values), index=features.index, columns=features.index)

# %%
euc_dist = pd.DataFrame(euclidean_distances(features.values), index=features.index, columns=features.index)

# %%
e = euc_dist.loc[pulisic_id]
c = cos_dist.loc[pulisic_id]

# %%
plt.figure(figsize=(11, 9))
plt.scatter(e, 1 - c);

# %%
c.nsmallest(5).index[1]
# Out:
# 211110

# %%
e.nsmallest(5)
# Out:
# id
# 158023     0.000000
# 190871    37.363083
# 211110    38.755645
# 183277    42.497059
# 9014      48.270074
# Name: 158023, dtype: float64

# %%
data.loc[c.nsmallest(5).index[1], "name"]
# Out:
# 'P. Dybala'

# %%
players_corr_matrix = features.T.corr()

# %%
# plt.scatterplayers_corr_matrix[pulisic_id].values

# %%
data.loc[players_corr_matrix[pulisic_id].nlargest(20).index[1:]]
# Out:
#                  name  age  nationality  overall  potential  \
# id
# 211110      P. Dybala   24    Argentina       89         94
# 190871      Neymar Jr   26       Brazil       92         93
# 192722     R. Hamouma   31       France       76         76
# 9014        A. Robben   34  Netherlands       84         84
# 222737         Malcom   21       Brazil       82         89
# 190544      A. Ljajić   26       Serbia       80         81
# 176635        M. Özil   29      Germany       86         86
# 210372     R. Ghezzal   26      Algeria       75         76
# 188042      M. Suárez   30    Argentina       75         75
# 201313       C. Ciano   28        Italy       75         75
# 183277      E. Hazard   27      Belgium       91         91
# 244261       L. Majer   20      Croatia       71         83
# 159171         Jurado   32        Spain       78         78
# 176993          Bojan   27        Spain       75         75
# 204485      R. Mahrez   27      Algeria       85         85
# ...

# %%
rav = euc_dist.values.ravel()

# %%
rav.shape[0]*.1
# Out:
# 2639904.4000000004

# %%
rav_sample = np.random.choice(rav, size =2639904,  replace=False)

# %%
plt.hist(rav_sample)
# Out:
# (array([9.31000e+02, 2.34908e+05, 7.73882e+05, 7.45685e+05, 5.54280e+05,
#         2.55482e+05, 6.54470e+04, 8.66000e+03, 5.99000e+02, 3.00000e+01]),
#  array([  0.        ,  28.13520926,  56.27041852,  84.40562777,
#         112.54083703, 140.67604629, 168.81125555, 196.94646481,
#         225.08167407, 253.21688332, 281.35209258]),
#  <a list of 10 Patch objects>)

# %%
from sklearn.manifold import TSNE

# %%
from sklearn.metrics.pairwise import PAIRWISE_DISTANCE_FUNCTIONS

# %%
PAIRWISE_DISTANCE_FUNCTIONS.keys()
# Out:
# dict_keys(['cityblock', 'cosine', 'euclidean', 'l2', 'l1', 'manhattan', 'precomputed'])

# %%
tsne = TSNE(metric="cosine")
tsne_values = tsne.fit_transform(features)

# %%
plt.scatter(tsne_values[:, 0], tsne_values[:, 1])

# %%
from MulticoreTSNE import MulticoreTSNE as MTSNE

# %%
mtsne = MTSNE(n_jobs=4, perplexity=2, learning_rate=80, angle = 0.2)

# %%
Y = tsne.fit_transform(Xs)

# %%
features.columns
# Out:
# Index(['crossing', 'finishing', 'headingaccuracy', 'shortpassing', 'volleys',
#        'dribbling', 'curve', 'fkaccuracy', 'longpassing', 'ballcontrol',
#        'acceleration', 'sprintspeed', 'agility', 'reactions', 'balance',
#        'shotpower', 'jumping', 'stamina', 'strength', 'longshots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standingtackle', 'slidingtackle'],
#       dtype='object')

# %%
plt.figure(figsize=(11, 9))
plt.scatter(Y[:, 0], Y[:, 1], c = data.headingaccuracy, alpha=.25, cmap = "seismic")
plt.colorbar()

# %%
mtsne.
# Out:
# 0.2
